# %% [markdown]
# # Viikko 2-3
#  - kolmas viikko

# %%
import numpy as np
import matplotlib.pyplot as plt

kuva = np.ones((5,5))
kuva[:,1] = 10*np.ones(5)

print(kuva)
print(kuva.shape)
print()
print()
suodatin = np.zeros((3,3))
suodatin[:,0] = -np.ones(3)
suodatin[:,2] = np.ones(3)

print(suodatin.shape)
print(suodatin.dtype)

plt.figure(1)
plt.subplot(2,2,1)
plt.plot(suodatin[:,:])
plt.figure(2)
plt.plot(2,2,2)
plt.stem(np.arange(10))
plt.show()
# Out:
# [[ 1. 10.  1.  1.  1.]
#  [ 1. 10.  1.  1.  1.]
#  [ 1. 10.  1.  1.  1.]
#  [ 1. 10.  1.  1.  1.]
#  [ 1. 10.  1.  1.  1.]]
# (5, 5)
#
#
# (3, 3)
# float64
